# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_trend_one=pd.read_csv('./trends/crcard.csv',index_col=0,parse_dates=True)[['Close']]
df_trend_one=df_trend_one.sort_index()

# %%
df_trend_one.plot(figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_trend_one.index
# Out:
# DatetimeIndex(['2017-10-03', '2017-10-02', '2017-10-01', '2017-09-30',
#                '2017-09-29', '2017-09-28', '2017-09-27', '2017-09-26',
#                '2017-09-25', '2017-09-24',
#                ...
#                '2006-10-31', '2006-10-30', '2006-10-29', '2006-10-28',
#                '2006-10-27', '2006-10-26', '2006-10-25', '2006-10-24',
#                '2006-10-23', '2006-10-22'],
#               dtype='datetime64[ns]', name='Date', length=4000, freq=None)

# %%
pd.read_csv('./data/crcard.csv')
# Out:
#              Category: All categories
# Month    Credit card: (United States)
# 2004-01                            37
# 2004-02                            37
# 2004-03                            39
# 2004-04                            37
# ...                               ...
# 2020-07                            86
# 2020-08                            80
# 2020-09                            78
# 2020-10                            81
# 2020-11                            80
#
# [204 rows x 1 columns]

# %%
from pytrends.request import TrendReq

pytrends = TrendReq(hl='en-US', tz=360)

# %%
kw_list = ["Credit Card"]
pytrends.build_payload(kw_list, cat=0, timeframe='all', geo='US', gprop='')

# %%
pytrends.interest_over_time()
# Out:
#             Credit Card isPartial
# date
# 2004-01-01           36     False
# 2004-02-01           34     False
# 2004-03-01           36     False
# 2004-04-01           34     False
# 2004-05-01           36     False
# ...                 ...       ...
# 2020-07-01           84     False
# 2020-08-01           77     False
# 2020-09-01           80     False
# 2020-10-01           83     False
# 2020-11-01           82      True
#
# [203 rows x 2 columns]

# %%
from pytrends import dailydata

df = dailydata.get_daily_data('credit card', 2016, 1, 2016, 12, geo = 'BR')
# Out:
# credit card:2016-01-01 2016-01-31
# credit card:2016-02-01 2016-02-29
# credit card:2016-03-01 2016-03-31
# credit card:2016-04-01 2016-04-30
# credit card:2016-05-01 2016-05-31
# credit card:2016-06-01 2016-06-30
# credit card:2016-07-01 2016-07-31
# credit card:2016-08-01 2016-08-31
# credit card:2016-09-01 2016-09-30
# credit card:2016-10-01 2016-10-31
# credit card:2016-11-01 2016-11-30
# credit card:2016-12-01 2016-12-31
#             credit card_unscaled  credit card_monthly isPartial  scale  \
# date
# 2016-01-01                    62                  NaN       NaN    NaN
# 2016-01-02                    96                  NaN       NaN    NaN
# 2016-01-03                    81                 89.0     False   0.89
# 2016-01-04                   100                 89.0       NaN   0.89
# 2016-01-05                    75                 89.0       NaN   0.89
# ...                          ...                  ...       ...    ...
# ...

# %%
df
# Out:
#             credit card_unscaled  credit card_monthly isPartial  scale  \
# date
# 2016-01-01                    62                  NaN       NaN    NaN
# 2016-01-02                    96                  NaN       NaN    NaN
# 2016-01-03                    81                 89.0     False   0.89
# 2016-01-04                   100                 89.0       NaN   0.89
# 2016-01-05                    75                 89.0       NaN   0.89
# ...                          ...                  ...       ...    ...
# 2016-12-27                    57                 70.0       NaN   0.70
# 2016-12-28                    78                 70.0       NaN   0.70
# 2016-12-29                    40                 70.0       NaN   0.70
# 2016-12-30                    56                 70.0       NaN   0.70
# 2016-12-31                    27                 70.0       NaN   0.70
#
#             credit card
# date
# 2016-01-01          NaN
# 2016-01-02          NaN
# 2016-01-03        72.09
# ...

# %%
df['credit card'].plot(figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_trend_one['2016-01-01':'2016-12-31'].plot(figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.plot(df['credit card'].values/(np.squeeze(df_trend_one['2016-01-01':'2016-12-31'].values)))

# %%
np.corrcoef(df['credit card'].values[2:],np.squeeze(df_trend_one['2016-01-01':'2016-12-31'].values[2:]))
# Out:
# array([[1.        , 0.01073441],
#        [0.01073441, 1.        ]])
